# %% [markdown]
# ## AutoML

# %% [markdown]
# ### 주요기술
# ![image.png](attachment:image.png)
# + 1. Auto Feature Engineering(AutoFE)
# + 2. Hyper Paramter Optimization(HPO)
# + 3. Neural Architecture Search(NAS)
# + 4. Meta Learning(Learning to learn)
